# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('/content/house_prices.csv')

# %%
df.head()
# Out:
#    sqft_living  bedrooms  bathrooms  floors  house_age  dist_to_city_km  \
# 0          959         4        2.0     2.0         10            13.97
# 1         3173         4        2.6     2.0          9             1.40
# 2         2017         1        1.9     1.0         71             0.24
# 3          818         5        3.7     1.5         45            13.07
# 4         2036         3        2.3     2.0         57             1.90
#
#    quality_score   price
# 0              6  256153
# 1              4  602494
# 2              9  403973
# 3              3  208514
# 4              5  396980

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe()
# Out:
#        sqft_living     bedrooms   bathrooms       floors    house_age  \
# count  1000.000000  1000.000000  988.000000  1000.000000  1000.000000
# mean   1872.225000     3.368000    2.528745     1.621500    19.530000
# std     721.658094     1.189955    0.963300     0.613077    18.964882
# min     450.000000     1.000000    1.000000     1.000000     0.000000
# 25%    1362.000000     3.000000    1.800000     1.000000     6.000000
# 50%    1873.500000     3.000000    2.500000     1.500000    13.000000
# 75%    2358.000000     4.000000    3.100000     2.000000    27.000000
# max    3927.000000     6.000000    5.000000     3.000000   100.000000
#
#        dist_to_city_km  quality_score         price
# count      1000.000000    1000.000000  1.000000e+03
# mean          8.020810       6.581000  4.081768e+05
# std           7.635918       2.240638  1.518990e+05
# min           0.200000       3.000000  8.956100e+04
# 25%           2.327500       5.000000  3.257180e+05
# 50%           5.690000       7.000000  4.020970e+05
# 75%          11.495000       9.000000  4.792382e+05
# max          46.160000      10.000000  2.558280e+06

# %%
df.isnull().sum()
# Out:
# sqft_living         0
# bedrooms            0
# bathrooms          12
# floors              0
# house_age           0
# dist_to_city_km     0
# quality_score       0
# price               0
# dtype: int64

# %%
df['bathrooms']=df['bathrooms'].fillna(df['bathrooms'].median())
df.isnull().sum()
# Out:
# sqft_living        0
# bedrooms           0
# bathrooms          0
# floors             0
# house_age          0
# dist_to_city_km    0
# quality_score      0
# price              0
# dtype: int64

# %%
q1=df['price'].quantile(0.25)
q3=df['price'].quantile(0.75)
iqr=q3-q1
upper=q3+1.5*iqr
df=df[df['price']<upper]
df.shape
# Out:
# (993, 8)

# %%
x=df.drop(columns='price')
y=df['price']

# %%
print(x)
# Out:
#      sqft_living  bedrooms  bathrooms  floors  house_age  dist_to_city_km  \
# 0            959         4        2.0     2.0         10            13.97
# 1           3173         4        2.6     2.0          9             1.40
# 2           2017         1        1.9     1.0         71             0.24
# 3            818         5        3.7     1.5         45            13.07
# 4           2036         3        2.3     2.0         57             1.90
# ..           ...       ...        ...     ...        ...              ...
# 995         2530         2        1.5     2.0          2             6.32
# 996         1159         3        2.1     2.5         12             1.00
# 997         2530         3        2.1     1.5         37             3.36
# 998          785         1        1.0     3.0          4             0.77
# 999         3076         3        2.2     2.0         19             5.67
#
#      quality_score
# 0                6
# 1                4
# 2                9
# 3                3
# 4                5
# ..             ...
# 995              3
# 996              5
# 997              9
# 998              5
# 999              6
#
# [993 rows x 7 columns]

# %%
print(y)
# Out:
# 0      256153
# 1      602494
# 2      403973
# 3      208514
# 4      396980
#         ...
# 995    442706
# 996    290977
# 997    512494
# 998    242206
# 999    574995
# Name: price, Length: 993, dtype: int64

# %%
scaler = StandardScaler()

# %%
scaler.fit(x)
x_std=scaler.transform(x)

# %%
print(x_std)
# Out:
# [[-1.27005373  0.53184711 -0.54995639 ... -0.50463434  0.77541051
#   -0.25823263]
#  [ 1.83426726  0.53184711  0.07547598 ... -0.55729322 -0.86770085
#   -1.15325883]
#  [ 0.21340228 -1.98702816 -0.65419511 ...  2.70755733 -1.01933244
#    1.08430666]
#  ...
#  [ 0.93269617 -0.30777798 -0.44571766 ...  0.91715542 -0.61149574
#    1.08430666]
#  [-1.51402475 -1.98702816 -1.59234366 ... -0.82058762 -0.95005249
#   -0.70574573]
#  [ 1.69826042 -0.30777798 -0.34147893 ... -0.03070442 -0.30953971
#   -0.25823263]]

# %%
x=x_std

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (993, 7) (794, 7) (199, 7)

# %%
cf=RandomForestRegressor(n_estimators=200,max_depth=10,random_state=2)

# %%
cf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=200, random_state=2)

# %%
x_train_pred=cf.predict(x_train)

# %%
x_train_r2=r2_score(y_train,x_train_pred)

# %%
print(x_train_r2)
# Out:
# 0.9908600329907643

# %%
print(x_train_r2)
# Out:
# 0.9908600329907643

# %%
data=[2150,3,2.0,2.0,8,5.4,7]
print(data)
# Out:
# [2150, 3, 2.0, 2.0, 8, 5.4, 7]

# %%
data_np=np.asarray(data)
print(data_np)
# Out:
# [2.15e+03 3.00e+00 2.00e+00 2.00e+00 8.00e+00 5.40e+00 7.00e+00]

# %%
data_reshape=data_np.reshape(1,-1)

# %%
input_std=scaler.transform(data_reshape)

# %%
print(input_std)
# Out:
# [[2.15e+03 3.00e+00 2.00e+00 2.00e+00 8.00e+00 5.40e+00 7.00e+00]]

# %%
pred=cf.predict(input_std)
print(pred)
# Out:
# [568384.885]
